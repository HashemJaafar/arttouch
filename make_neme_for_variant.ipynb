# %%
import pandas as pd
sheet_id ="1hiGgbNVlCv-Cn3h5uqRntVOCBNTKIkQAW-FZSej-HFo"
sheet_name = "سلة"
url = f"https://docs.google.com/spreadsheets/d/1hiGgbNVlCv-Cn3h5uqRntVOCBNTKIkQAW-FZSej-HFo/edit#gid=0"

pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[5], line 6
#       3 sheet_name = "سلة"
#       4 url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
# ----> 6 pd.read_csv(url)
#
# ...
